# %%
# Cell 1: Import necessary libraries
import os
import numpy as np
import pandas as pd
from scipy.signal import butter, filtfilt
from sklearn.model_selection import train_test_split
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv1D, MaxPooling1D, Flatten, Dense
from tensorflow.keras.optimizers import Adam
from sklearn.metrics import accuracy_score

# %%
# Cell 2: Define paths and parameters
input_data_path = "D:/AI/EEG_v2/data/input"
output_data_path = "D:/AI/EEG_v2/data/output"

# Parameters
sampling_rate = 100  # 100 Hz
epoch_length = 30 * sampling_rate  # 30 seconds
n_train = 454  # Use first 160 for training, remaining for validation

# %%
# Cell 3: Bandpass filter function
def bandpass_filter(signal, lowcut=0.5, highcut=30, fs=100, order=4):
    nyquist = 0.5 * fs
    low = lowcut / nyquist
    high = highcut / nyquist
    b, a = butter(order, [low, high], btype='band')
    return filtfilt(b, a, signal)

# %%
# Cell 4: Load and preprocess data function
def load_and_preprocess_data(input_path, output_path, n_patients):
    X, y = [], []
    for i in range(1, n_patients + 1):
        # Load input EEG signal
        eeg_file = os.path.join(input_path, f"subject_{i}.csv")
        output_file = os.path.join(output_path, f"subject_{i}.csv")
        
        # Load EEG and output (pain score)
        eeg_data = pd.read_csv(eeg_file, header=None).squeeze().values
        pain_score = pd.read_csv(output_file, header=None).squeeze().item()  # Corrected to use .item()
        
        # Apply bandpass filter
        eeg_filtered = bandpass_filter(eeg_data)
        
        # Segment into 30-second epochs
        epochs = [eeg_filtered[j:j+epoch_length] for j in range(0, len(eeg_filtered), epoch_length)]
        epochs = [epoch for epoch in epochs if len(epoch) == epoch_length]  # Filter incomplete epochs

        X.extend(epochs)
        y.extend([pain_score] * len(epochs))
        print(f'Patient {i} data loaded')
    
    return np.array(X), np.array(y)

# %%
# Cell 5: Load and preprocess data
X, y = load_and_preprocess_data(input_data_path, output_data_path, 568)

# Split data into train and validation sets
X_train, X_val, y_train, y_val = train_test_split(X, y, train_size=n_train, stratify=y)
# Out:
# Patient 1 data loaded
# Patient 2 data loaded
# Patient 3 data loaded
# Patient 4 data loaded
# Patient 5 data loaded
# Patient 6 data loaded
# Patient 7 data loaded
# Patient 8 data loaded
# Patient 9 data loaded
# Patient 10 data loaded
# Patient 11 data loaded
# Patient 12 data loaded
# Patient 13 data loaded
# Patient 14 data loaded
# Patient 15 data loaded
# Patient 16 data loaded
# Patient 17 data loaded
# Patient 18 data loaded
# Patient 19 data loaded
# Patient 20 data loaded
# Patient 21 data loaded
# Patient 22 data loaded
# Patient 23 data loaded
# Patient 24 data loaded
# Patient 25 data loaded
# Patient 26 data loaded
# Patient 27 data loaded
# Patient 28 data loaded
# Patient 29 data loaded
# Patient 30 data loaded
# Patient 31 data loaded
# Patient 32 data loaded
# Patient 33 data loaded
# Patient 34 data loaded
# Patient 35 data loaded
# Patient 36 data loaded
# Patient 37 data loaded
# Patient 38 data loaded
# Patient 39 data loaded
# Patient 40 data loaded
# Patient 41 data loaded
# Patient 42 data loaded
# Patient 43 data loaded
# Patient 44 data loaded
# Patient 45 data loaded
# Patient 46 data loaded
# Patient 47 data loaded
# Patient 48 data loaded
# Patient 49 data loaded
# Patient 50 data loaded
# Patient 51 data loaded
# Patient 52 data loaded
# Patient 53 data loaded
# Patient 54 data loaded
# Patient 55 data loaded
# Patient 56 data loaded
# Patient 57 data loaded
# Patient 58 data loaded
# Patient 59 data loaded
# Patient 60 data loaded
# Patient 61 data loaded
# Patient 62 data loaded
# Patient 63 data loaded
# Patient 64 data loaded
# Patient 65 data loaded
# Patient 66 data loaded
# Patient 67 data loaded
# Patient 68 data loaded
# Patient 69 data loaded
# Patient 70 data loaded
# Patient 71 data loaded
# Patient 72 data loaded
# Patient 73 data loaded
# Patient 74 data loaded
# Patient 75 data loaded
# Patient 76 data loaded
# Patient 77 data loaded
# Patient 78 data loaded
# Patient 79 data loaded
# Patient 80 data loaded
# Patient 81 data loaded
# Patient 82 data loaded
# Patient 83 data loaded
# Patient 84 data loaded
# Patient 85 data loaded
# Patient 86 data loaded
# Patient 87 data loaded
# Patient 88 data loaded
# Patient 89 data loaded
# Patient 90 data loaded
# Patient 91 data loaded
# Patient 92 data loaded
# Patient 93 data loaded
# Patient 94 data loaded
# Patient 95 data loaded
# Patient 96 data loaded
# Patient 97 data loaded
# Patient 98 data loaded
# Patient 99 data loaded
# Patient 100 data loaded
# Patient 101 data loaded
# Patient 102 data loaded
# Patient 103 data loaded
# Patient 104 data loaded
# Patient 105 data loaded
# Patient 106 data loaded
# Patient 107 data loaded
# Patient 108 data loaded
# Patient 109 data loaded
# Patient 110 data loaded
# Patient 111 data loaded
# Patient 112 data loaded
# Patient 113 data loaded
# Patient 114 data loaded
# Patient 115 data loaded
# Patient 116 data loaded
# Patient 117 data loaded
# Patient 118 data loaded
# Patient 119 data loaded
# Patient 120 data loaded
# Patient 121 data loaded
# Patient 122 data loaded
# Patient 123 data loaded
# Patient 124 data loaded
# Patient 125 data loaded
# Patient 126 data loaded
# Patient 127 data loaded
# Patient 128 data loaded
# Patient 129 data loaded
# Patient 130 data loaded
# Patient 131 data loaded
# Patient 132 data loaded
# Patient 133 data loaded
# Patient 134 data loaded
# Patient 135 data loaded
# Patient 136 data loaded
# Patient 137 data loaded
# Patient 138 data loaded
# Patient 139 data loaded
# Patient 140 data loaded
# Patient 141 data loaded
# Patient 142 data loaded
# Patient 143 data loaded
# Patient 144 data loaded
# Patient 145 data loaded
# Patient 146 data loaded
# Patient 147 data loaded
# Patient 148 data loaded
# Patient 149 data loaded
# Patient 150 data loaded
# Patient 151 data loaded
# Patient 152 data loaded
# Patient 153 data loaded
# Patient 154 data loaded
# Patient 155 data loaded
# Patient 156 data loaded
# Patient 157 data loaded
# Patient 158 data loaded
# Patient 159 data loaded
# Patient 160 data loaded
# Patient 161 data loaded
# Patient 162 data loaded
# Patient 163 data loaded
# Patient 164 data loaded
# Patient 165 data loaded
# Patient 166 data loaded
# Patient 167 data loaded
# Patient 168 data loaded
# Patient 169 data loaded
# Patient 170 data loaded
# Patient 171 data loaded
# Patient 172 data loaded
# Patient 173 data loaded
# Patient 174 data loaded
# Patient 175 data loaded
# Patient 176 data loaded
# Patient 177 data loaded
# Patient 178 data loaded
# Patient 179 data loaded
# Patient 180 data loaded
# Patient 181 data loaded
# Patient 182 data loaded
# Patient 183 data loaded
# Patient 184 data loaded
# Patient 185 data loaded
# Patient 186 data loaded
# Patient 187 data loaded
# Patient 188 data loaded
# Patient 189 data loaded
# Patient 190 data loaded
# Patient 191 data loaded
# Patient 192 data loaded
# Patient 193 data loaded
# Patient 194 data loaded
# Patient 195 data loaded
# Patient 196 data loaded
# Patient 197 data loaded
# Patient 198 data loaded
# Patient 199 data loaded
# Patient 200 data loaded
# Patient 201 data loaded
# Patient 202 data loaded
# Patient 203 data loaded
# Patient 204 data loaded
# Patient 205 data loaded
# Patient 206 data loaded
# Patient 207 data loaded
# Patient 208 data loaded
# Patient 209 data loaded
# Patient 210 data loaded
# Patient 211 data loaded
# Patient 212 data loaded
# Patient 213 data loaded
# Patient 214 data loaded
# Patient 215 data loaded
# Patient 216 data loaded
# Patient 217 data loaded
# Patient 218 data loaded
# Patient 219 data loaded
# Patient 220 data loaded
# Patient 221 data loaded
# Patient 222 data loaded
# Patient 223 data loaded
# Patient 224 data loaded
# Patient 225 data loaded
# Patient 226 data loaded
# Patient 227 data loaded
# Patient 228 data loaded
# Patient 229 data loaded
# Patient 230 data loaded
# Patient 231 data loaded
# Patient 232 data loaded
# Patient 233 data loaded
# Patient 234 data loaded
# Patient 235 data loaded
# Patient 236 data loaded
# Patient 237 data loaded
# Patient 238 data loaded
# Patient 239 data loaded
# Patient 240 data loaded
# Patient 241 data loaded
# Patient 242 data loaded
# Patient 243 data loaded
# Patient 244 data loaded
# Patient 245 data loaded
# Patient 246 data loaded
# Patient 247 data loaded
# Patient 248 data loaded
# Patient 249 data loaded
# Patient 250 data loaded
# Patient 251 data loaded
# Patient 252 data loaded
# Patient 253 data loaded
# Patient 254 data loaded
# Patient 255 data loaded
# Patient 256 data loaded
# Patient 257 data loaded
# Patient 258 data loaded
# Patient 259 data loaded
# Patient 260 data loaded
# Patient 261 data loaded
# Patient 262 data loaded
# Patient 263 data loaded
# Patient 264 data loaded
# Patient 265 data loaded
# Patient 266 data loaded
# Patient 267 data loaded
# Patient 268 data loaded
# Patient 269 data loaded
# Patient 270 data loaded
# Patient 271 data loaded
# Patient 272 data loaded
# Patient 273 data loaded
# Patient 274 data loaded
# Patient 275 data loaded
# Patient 276 data loaded
# Patient 277 data loaded
# Patient 278 data loaded
# Patient 279 data loaded
# Patient 280 data loaded
# Patient 281 data loaded
# Patient 282 data loaded
# Patient 283 data loaded
# Patient 284 data loaded
# Patient 285 data loaded
# Patient 286 data loaded
# Patient 287 data loaded
# Patient 288 data loaded
# Patient 289 data loaded
# Patient 290 data loaded
# Patient 291 data loaded
# Patient 292 data loaded
# Patient 293 data loaded
# Patient 294 data loaded
# Patient 295 data loaded
# Patient 296 data loaded
# Patient 297 data loaded
# Patient 298 data loaded
# Patient 299 data loaded
# Patient 300 data loaded
# Patient 301 data loaded
# Patient 302 data loaded
# Patient 303 data loaded
# Patient 304 data loaded
# Patient 305 data loaded
# Patient 306 data loaded
# Patient 307 data loaded
# Patient 308 data loaded
# Patient 309 data loaded
# Patient 310 data loaded
# Patient 311 data loaded
# Patient 312 data loaded
# Patient 313 data loaded
# Patient 314 data loaded
# Patient 315 data loaded
# Patient 316 data loaded
# Patient 317 data loaded
# Patient 318 data loaded
# Patient 319 data loaded
# Patient 320 data loaded
# Patient 321 data loaded
# Patient 322 data loaded
# Patient 323 data loaded
# Patient 324 data loaded
# Patient 325 data loaded
# Patient 326 data loaded
# Patient 327 data loaded
# Patient 328 data loaded
# Patient 329 data loaded
# Patient 330 data loaded
# Patient 331 data loaded
# Patient 332 data loaded
# Patient 333 data loaded
# Patient 334 data loaded
# Patient 335 data loaded
# Patient 336 data loaded
# Patient 337 data loaded
# Patient 338 data loaded
# Patient 339 data loaded
# Patient 340 data loaded
# Patient 341 data loaded
# Patient 342 data loaded
# Patient 343 data loaded
# Patient 344 data loaded
# Patient 345 data loaded
# Patient 346 data loaded
# Patient 347 data loaded
# Patient 348 data loaded
# Patient 349 data loaded
# Patient 350 data loaded
# Patient 351 data loaded
# Patient 352 data loaded
# Patient 353 data loaded
# Patient 354 data loaded
# Patient 355 data loaded
# Patient 356 data loaded
# Patient 357 data loaded
# Patient 358 data loaded
# Patient 359 data loaded
# Patient 360 data loaded
# Patient 361 data loaded
# Patient 362 data loaded
# Patient 363 data loaded
# Patient 364 data loaded
# Patient 365 data loaded
# Patient 366 data loaded
# Patient 367 data loaded
# Patient 368 data loaded
# Patient 369 data loaded
# Patient 370 data loaded
# Patient 371 data loaded
# Patient 372 data loaded
# Patient 373 data loaded
# Patient 374 data loaded
# Patient 375 data loaded
# Patient 376 data loaded
# Patient 377 data loaded
# Patient 378 data loaded
# Patient 379 data loaded
# Patient 380 data loaded
# Patient 381 data loaded
# Patient 382 data loaded
# Patient 383 data loaded
# Patient 384 data loaded
# Patient 385 data loaded
# Patient 386 data loaded
# Patient 387 data loaded
# Patient 388 data loaded
# Patient 389 data loaded
# Patient 390 data loaded
# Patient 391 data loaded
# Patient 392 data loaded
# Patient 393 data loaded
# Patient 394 data loaded
# Patient 395 data loaded
# Patient 396 data loaded
# Patient 397 data loaded
# Patient 398 data loaded
# Patient 399 data loaded
# Patient 400 data loaded
# Patient 401 data loaded
# Patient 402 data loaded
# Patient 403 data loaded
# Patient 404 data loaded
# Patient 405 data loaded
# Patient 406 data loaded
# Patient 407 data loaded
# Patient 408 data loaded
# Patient 409 data loaded
# Patient 410 data loaded
# Patient 411 data loaded
# Patient 412 data loaded
# Patient 413 data loaded
# Patient 414 data loaded
# Patient 415 data loaded
# Patient 416 data loaded
# Patient 417 data loaded
# Patient 418 data loaded
# Patient 419 data loaded
# Patient 420 data loaded
# Patient 421 data loaded
# Patient 422 data loaded
# Patient 423 data loaded
# Patient 424 data loaded
# Patient 425 data loaded
# Patient 426 data loaded
# Patient 427 data loaded
# Patient 428 data loaded
# Patient 429 data loaded
# Patient 430 data loaded
# Patient 431 data loaded
# Patient 432 data loaded
# Patient 433 data loaded
# Patient 434 data loaded
# Patient 435 data loaded
# Patient 436 data loaded
# Patient 437 data loaded
# Patient 438 data loaded
# Patient 439 data loaded
# Patient 440 data loaded
# Patient 441 data loaded
# Patient 442 data loaded
# Patient 443 data loaded
# Patient 444 data loaded
# Patient 445 data loaded
# Patient 446 data loaded
# Patient 447 data loaded
# Patient 448 data loaded
# Patient 449 data loaded
# Patient 450 data loaded
# Patient 451 data loaded
# Patient 452 data loaded
# Patient 453 data loaded
# Patient 454 data loaded
# Patient 455 data loaded
# Patient 456 data loaded
# Patient 457 data loaded
# Patient 458 data loaded
# Patient 459 data loaded
# Patient 460 data loaded
# Patient 461 data loaded
# Patient 462 data loaded
# Patient 463 data loaded
# Patient 464 data loaded
# Patient 465 data loaded
# Patient 466 data loaded
# Patient 467 data loaded
# Patient 468 data loaded
# Patient 469 data loaded
# Patient 470 data loaded
# Patient 471 data loaded
# Patient 472 data loaded
# Patient 473 data loaded
# Patient 474 data loaded
# Patient 475 data loaded
# Patient 476 data loaded
# Patient 477 data loaded
# Patient 478 data loaded
# Patient 479 data loaded
# Patient 480 data loaded
# Patient 481 data loaded
# Patient 482 data loaded
# Patient 483 data loaded
# Patient 484 data loaded
# Patient 485 data loaded
# Patient 486 data loaded
# Patient 487 data loaded
# Patient 488 data loaded
# Patient 489 data loaded
# Patient 490 data loaded
# Patient 491 data loaded
# Patient 492 data loaded
# Patient 493 data loaded
# Patient 494 data loaded
# Patient 495 data loaded
# Patient 496 data loaded
# Patient 497 data loaded
# Patient 498 data loaded
# Patient 499 data loaded
# Patient 500 data loaded
# Patient 501 data loaded
# Patient 502 data loaded
# Patient 503 data loaded
# Patient 504 data loaded
# Patient 505 data loaded
# Patient 506 data loaded
# Patient 507 data loaded
# Patient 508 data loaded
# Patient 509 data loaded
# Patient 510 data loaded
# Patient 511 data loaded
# Patient 512 data loaded
# Patient 513 data loaded
# Patient 514 data loaded
# Patient 515 data loaded
# Patient 516 data loaded
# Patient 517 data loaded
# Patient 518 data loaded
# Patient 519 data loaded
# Patient 520 data loaded
# Patient 521 data loaded
# Patient 522 data loaded
# Patient 523 data loaded
# Patient 524 data loaded
# Patient 525 data loaded
# Patient 526 data loaded
# Patient 527 data loaded
# Patient 528 data loaded
# Patient 529 data loaded
# Patient 530 data loaded
# Patient 531 data loaded
# Patient 532 data loaded
# Patient 533 data loaded
# Patient 534 data loaded
# Patient 535 data loaded
# Patient 536 data loaded
# Patient 537 data loaded
# Patient 538 data loaded
# Patient 539 data loaded
# Patient 540 data loaded
# Patient 541 data loaded
# Patient 542 data loaded
# Patient 543 data loaded
# Patient 544 data loaded
# Patient 545 data loaded
# Patient 546 data loaded
# Patient 547 data loaded
# Patient 548 data loaded
# Patient 549 data loaded
# Patient 550 data loaded
# Patient 551 data loaded
# Patient 552 data loaded
# Patient 553 data loaded
# Patient 554 data loaded
# Patient 555 data loaded
# Patient 556 data loaded
# Patient 557 data loaded
# Patient 558 data loaded
# Patient 559 data loaded
# Patient 560 data loaded
# Patient 561 data loaded
# Patient 562 data loaded
# Patient 563 data loaded
# Patient 564 data loaded
# Patient 565 data loaded
# Patient 566 data loaded
# Patient 567 data loaded
# Patient 568 data loaded

# %%
def display_preprocessed_data(X, y, num_samples=5):
    print("Shape of X (epochs):", X.shape)
    print("Shape of y (pain scores):", y.shape)
    
    # Display a few sample epochs and their associated pain scores
    for i in range(min(num_samples, len(X))):
        print(f"\nSample {i + 1} - Pain Score: {y[i]}")
        print("Epoch Data:", X[i])
display_preprocessed_data(X, y)
# Out:
# Shape of X (epochs): (184446, 3000)
# Shape of y (pain scores): (184446,)
#
# Sample 1 - Pain Score: 0
# Epoch Data: [-2.03257434e-08 -2.00767200e-08 -1.98061197e-08 ...  1.48874150e+01
#   1.47843686e+01  1.46639936e+01]
#
# Sample 2 - Pain Score: 0
# Epoch Data: [  14.52599622   14.37009338   14.19601324 ...  -66.83416634  -77.22651686
#  -118.8334868 ]
#
# Sample 3 - Pain Score: 0
# Epoch Data: [-116.29800947  -47.28860273    0.28009865 ...  -56.32949372 -103.27844477
#  -104.54812917]
#
# Sample 4 - Pain Score: 0
# Epoch Data: [ -71.84881838  -85.0653995  -153.81425542 ... -180.4530775  -161.67551787
#  -175.59272382]
#
# Sample 5 - Pain Score: 0
# Epoch Data: [-191.29142281 -194.54457643 -194.90515338 ...  -43.83793328  -43.72499164
#   -55.12049039]

# %%
# Cell 6: Define 1D CNN model function
def build_1d_cnn(input_shape):
    model = Sequential([
        Conv1D(32, kernel_size=3, activation='relu', input_shape=input_shape),
        MaxPooling1D(pool_size=2),
        Conv1D(64, kernel_size=3, activation='relu'),
        MaxPooling1D(pool_size=2),
        Flatten(),
        Dense(128, activation='relu'),
        Dense(4, activation='softmax')  # 4 outputs for classes 0, 1, 2, 3
    ])
    model.compile(optimizer=Adam(learning_rate=0.001), loss='sparse_categorical_crossentropy', metrics=['accuracy'])
    return model

# %%
# Cell 7: Prepare data for CNN model
input_shape = (X_train.shape[1], 1)  # Shape of each epoch
X_train = X_train[..., np.newaxis]
X_val = X_val[..., np.newaxis]

# %%
# Cell 8: Build, train, and evaluate model
model = build_1d_cnn(input_shape)

history = model.fit(X_train, y_train, epochs=10, batch_size=32, validation_data=(X_val, y_val))
# Out:
# c:\Users\Admin\AppData\Local\Programs\Python\Python312\Lib\site-packages\keras\src\layers\convolutional\base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Epoch 1/10
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 83s 6s/step - accuracy: 0.3434 - loss: 125.4580 - val_accuracy: 0.5093 - val_loss: 41.7059
# Epoch 2/10
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 52s 4s/step - accuracy: 0.5016 - loss: 20.9048 - val_accuracy: 0.2055 - val_loss: 4.7234
# Epoch 3/10
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 53s 4s/step - accuracy: 0.4466 - loss: 1.9826 - val_accuracy: 0.4824 - val_loss: 1.4718
# Epoch 4/10
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 55s 4s/step - accuracy: 0.6947 - loss: 0.9272 - val_accuracy: 0.5037 - val_loss: 1.5162
# Epoch 5/10
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 65s 5s/step - accuracy: 0.7115 - loss: 0.7334 - val_accuracy: 0.4652 - val_loss: 1.8136
# Epoch 6/10
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 67s 5s/step - accuracy: 0.8103 - loss: 0.5915 - val_accuracy: 0.5004 - val_loss: 1.9686
# Epoch 7/10
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 70s 5s/step - accuracy: 0.8416 - loss: 0.4256 - val_accuracy: 0.4615 - val_loss: 2.0311
# Epoch 8/10
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 75s 5s/step - accuracy: 0.9367 - loss: 0.2526 - val_accuracy: 0.4842 - val_loss: 3.1181
# Epoch 9/10
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 81s 6s/step - accuracy: 0.9638 - loss: 0.5057 - val_accuracy: 0.4891 - val_loss: 3.5015
# Epoch 10/10
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 90s 6s/step - accuracy: 0.9843 - loss: 0.1380 - val_accuracy: 0.4885 - val_loss: 4.2825

# %%
# Evaluate on validation data
y_pred_probs = model.predict(X_val)  # Shape: (num_samples, 4)
y_pred_classes = np.argmax(y_pred_probs, axis=1)  # Shape: (num_samples,)
accuracy = accuracy_score(y_val, y_pred_classes)
print(f"Validation Accuracy: {accuracy * 100:.2f}%")
# Out:
# 5750/5750 ━━━━━━━━━━━━━━━━━━━━ 50s 9ms/step
# Validation Accuracy: 48.85%
